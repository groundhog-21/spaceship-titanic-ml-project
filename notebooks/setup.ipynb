# %%
import os

# Root directory (already created)
root = r"C:\Users\agbro\OneDrive\Desktop\Jupyter - VS Code\spaceship-titanic-ml-project"

# Folder structure
folders = [
    "data/raw",
    "data/interim",
    "data/processed",
    "notebooks",
    "src/data",
    "src/features",
    "src/models",
    "src/visualization",
    "submissions"
]

# Create directories
for folder in folders:
    path = os.path.join(root, folder)
    os.makedirs(path, exist_ok=True)
    print(f"Created (or already exists): {path}")

print("\nFolder structure setup complete!")

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn jupyterlab
# !pip install xgboost lightgbm catboost
